# %%
import os
import sys
from pia_unet_quantile import *
from constants import *
from utils_q import *
from ap import *
from plotters_unet_qunatile import *
sys.path.append(os. path.join(os.path.dirname(os.getcwd()), 'general/'))
from data_loader import *
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
intras_test,extras_test =data_prep_test (data,trains,raw = False)

# %%
loc = 'results/'
physics = True
UNET_HYPERPARAMS_quantile['physics']=physics
UNET_HYPERPARAMS_quantile['loss_data_q1']= quantile_loss(0.05)
UNET_HYPERPARAMS_quantile['loss_data_q2']= quantile_loss(0.5)
UNET_HYPERPARAMS_quantile['loss_data_q3']= quantile_loss(0.95)
model = train_and_save_model_quantile(UNET_HYPERPARAMS_quantile,loc, data, trains, tests, extras_test, intras_test,trains_with_limits,max_samples)
# Out:
# (560, 8000) (560, 8000)
# (1966, 8000) (1966, 8000)
# cbr1: (None, 8000, 32) 32
# re1: (None, 8000, 32)
# cbr2: (None, 1600, 64) 64
# re2: (None, 1600, 64)
# cbr3: (None, 320, 96) 96
# re3: (None, 320, 96)
# last_layer
# cbr4: (None, 64, 128) 128
# re4: (None, 64, 128)
# (None, 64, 96) x1 on shortcut
# (None, 64, 96) g1 on g
# (None, 64, 96) g1_x1
# (None, 64, 1) psi: conv on psi
# (None, 320, 1) psi_2 : psi_upsample5
# (None, 320, 96) x_psi * shortcut
# pre_co_-3 KerasTensor(type_spec=TensorSpec(shape=(None, 320, 128), dtype=tf.float32, name=None), name='up_sampling1d_1/concat:0', description="created by layer 'up_sampling1d_1'") (None, 64, 128) (None, 320, 96)
# aft_con-3 (None, 320, 224)
# cbr-4: (None, 320, 96)
# upS2 with 5 : (None, 320, 96)
# (None, 320, 64) x1 on shortcut
# (None, 320, 64) g1 on g
# (None, 320, 64) g1_x1
# (None, 320, 1) psi: conv on psi
# (None, 1600, 1) psi_2 : psi_upsample5
# (None, 1600, 64) x_psi * shortcut
# out_1_at (None, 1600, 64)
# d5 (None, 1600, 160)
# cbr-3: (None, 1600, 64)
# upS3 with 5 : (None, 1600, 64)
# (None, 1600, 32) x1 on shortcut
# (None, 1600, 32) g1 on g
# (None, 1600, 32) g1_x1
# (None, 1600, 1) psi: conv on psi
# (None, 8000, 1) psi_2 : psi_upsample5
# (None, 8000, 32) x_psi * shortcut
# pre_co_-2 (None, 1600, 64) (None, 8000, 32)
# aft_con-1 (None, 8000, 32)
# ph
# bk-noncom1 (None, 1600, 64)
# bk-noncom2 (None, 320, 96)
# bk-noncom3 (None, 64, 128)
# bk-noncom4 (None, 128)
# b (None, 128)
# b_1 (None, 8)
# a (None, 1, 1)
# k (None, 1, 1)
# x KerasTensor(type_spec=TensorSpec(shape=(3,), dtype=tf.int32, name=None), inferred_value=[None, 1, 1], name='tf.compat.v1.shape/Shape:0', description="created by layer 'tf.compat.v1.shape'")
# v_out2 (None, 8000, 1)
# dv_tnoq1 (None, 8000, 1)
# dv2_tnoq1 (None, 8000, 1)
# onesnoq1 (None, 8000, 1)
# inv_v (None, 8000, 1) KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tf.where_1/SelectV2:0', description="created by layer 'tf.where_1'")
# a_v (None, 8000, 1) KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='a_vnoq1/mul:0', description="created by layer 'a_vnoq1'")
# term_l1 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tl1noq1/mul_2:0', description="created by layer 'tl1noq1'")
# term_l2 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tl2noq1/mul:0', description="created by layer 'tl2noq1'")
# term_l3 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tf.math.truediv_3/truediv:0', description="created by layer 'tf.math.truediv_3'")
# term_l1 (None, 8000, 1)
# term_l2 (None, 8000, 1)
# term_l3 (None, 8000, 1)
# (None, 8000, 1)
# a (None, 1, 1)
# k (None, 1, 1)
# x KerasTensor(type_spec=TensorSpec(shape=(3,), dtype=tf.int32, name=None), inferred_value=[None, 1, 1], name='tf.compat.v1.shape_10/Shape:0', description="created by layer 'tf.compat.v1.shape_10'")
# v_out2 (None, 8000, 1)
# dv_tnoq2 (None, 8000, 1)
# dv2_tnoq2 (None, 8000, 1)
# onesnoq2 (None, 8000, 1)
# inv_v (None, 8000, 1) KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tf.where_3/SelectV2:0', description="created by layer 'tf.where_3'")
# a_v (None, 8000, 1) KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='a_vnoq2/mul:0', description="created by layer 'a_vnoq2'")
# term_l1 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tl1noq2/mul_2:0', description="created by layer 'tl1noq2'")
# term_l2 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tl2noq2/mul:0', description="created by layer 'tl2noq2'")
# term_l3 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tf.math.truediv_7/truediv:0', description="created by layer 'tf.math.truediv_7'")
# term_l1 (None, 8000, 1)
# term_l2 (None, 8000, 1)
# term_l3 (None, 8000, 1)
# (None, 8000, 1)
# a (None, 1, 1)
# k (None, 1, 1)
# x KerasTensor(type_spec=TensorSpec(shape=(3,), dtype=tf.int32, name=None), inferred_value=[None, 1, 1], name='tf.compat.v1.shape_20/Shape:0', description="created by layer 'tf.compat.v1.shape_20'")
# v_out2 (None, 8000, 1)
# dv_tnoq3 (None, 8000, 1)
# dv2_tnoq3 (None, 8000, 1)
# onesnoq3 (None, 8000, 1)
# inv_v (None, 8000, 1) KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tf.where_5/SelectV2:0', description="created by layer 'tf.where_5'")
# a_v (None, 8000, 1) KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='a_vnoq3/mul:0', description="created by layer 'a_vnoq3'")
# term_l1 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tl1noq3/mul_2:0', description="created by layer 'tl1noq3'")
# term_l2 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tl2noq3/mul:0', description="created by layer 'tl2noq3'")
# term_l3 KerasTensor(type_spec=TensorSpec(shape=(None, 8000, 1), dtype=tf.float32, name=None), name='tf.math.truediv_11/truediv:0', description="created by layer 'tf.math.truediv_11'")
# term_l1 (None, 8000, 1)
# term_l2 (None, 8000, 1)
# term_l3 (None, 8000, 1)
# (None, 8000, 1)
# train_target1 shape: (1966, 8000)
# dummy_train_ode shape: (1966, 7700, 1)
# dummy_train_dv shape: (1966, 8000, 1)
# dummy_train_sc shape: (1966, 1)
# val_target1 shape: (560, 8000)
# dummy_val_ode shape: (560, 7700, 1)
# dummy_val_dv shape: (560, 8000, 1)
# dummy_val_sc shape: (560, 1)
# Epoch 1/150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1054     _, original_func = tf_decorator.unwrap(python_func)
# -> 1055     func_outputs = python_func(*func_args, **func_kwargs)
#    1056
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         with OptionalXlaContext(compile_with_xla):
# --> 597           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     598         return out
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#
# /usr/lib/python3/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#
# /usr/lib/python3/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#
# /usr/lib/python3/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#
# /usr/lib/python3/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     459     return f(*args, **kwargs)
# --> 460   return f(*args)
#     461
#
# /usr/lib/python3/dist-packages/keras/engine/training.py in step_function(model, iterator)
#    1321             data = next(iterator)
# -> 1322             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1323             outputs = reduce_per_replica(
#
# /usr/lib/python3/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1672           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1674
#
# /usr/lib/python3/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    3249     with self._container_strategy().scope():
# -> 3250       return self._call_for_each_replica(fn, args, kwargs)
#    3251
#
# /usr/lib/python3/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    4047     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4048       return fn(*args, **kwargs)
#    4049
#
# /usr/lib/python3/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#
# /usr/lib/python3/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#
# /usr/lib/python3/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#
# /usr/lib/python3/dist-packages/keras/engine/training.py in run_step(data)
#    1302             def run_step(data):
# -> 1303                 outputs = model.train_step(data)
#    1304                 # Ensure counter is updated only if `train_step` succeeds.
#
# /usr/lib/python3/dist-packages/keras/engine/training.py in train_step(self, data)
#    1083         # Run backwards pass.
# -> 1084         self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#    1085         return self.compute_metrics(x, y, y_pred, sample_weight)
#
# /usr/lib/python3/dist-packages/keras/optimizers/optimizer.py in minimize(self, loss, var_list, tape)
#     542         """
# --> 543         grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     544         self.apply_gradients(grads_and_vars)
#
# /usr/lib/python3/dist-packages/keras/optimizers/optimizer.py in compute_gradients(self, loss, var_list, tape)
#     275
# --> 276         grads = tape.gradient(loss, var_list)
#     277         return list(zip(grads, var_list))
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1062
# -> 1063     flat_grad = imperative_grad.imperative_grad(
#    1064         self._tape,
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     145     with ops.name_scope(gradient_name_scope):
# --> 146       return grad_fn(mock_op, *out_grads)
#     147   else:
#
# /usr/lib/python3/dist-packages/tensorflow/python/ops/math_grad.py in _MulGrad(op, grad)
#    1368   (sx, rx, must_reduce_x), (sy, ry, must_reduce_y) = (
# -> 1369       SmartBroadcastGradientArgs(x, y, grad))
#    1370   x = math_ops.conj(x)
#
# /usr/lib/python3/dist-packages/tensorflow/python/ops/math_grad.py in SmartBroadcastGradientArgs(x, y, grad)
#     102       y_shape_tuple is None or None in y_shape_tuple):
# --> 103     sx = array_ops.shape_internal(x, optimize=False)
#     104     sy = array_ops.shape_internal(y, optimize=False)
#
# /usr/lib/python3/dist-packages/tensorflow/python/ops/array_ops.py in shape_internal(input, name, optimize, out_type)
#     694     else:
# --> 695       if not context.executing_eagerly():
#     696         input = ops.convert_to_tensor(input)
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/context.py in executing_eagerly()
#    2307
# -> 2308   return ctx.executing_eagerly()
#    2309
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/context.py in executing_eagerly(self)
#    1009
# -> 1010   def executing_eagerly(self):
#    1011     """Returns True if current thread has eager executing enabled."""
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_297465/3939064771.py in <module>
#       5 UNET_HYPERPARAMS_quantile['loss_data_q2']= quantile_loss(0.5)
#       6 UNET_HYPERPARAMS_quantile['loss_data_q3']= quantile_loss(0.95)
# ----> 7 model = train_and_save_model_quantile(UNET_HYPERPARAMS_quantile,loc, data, trains, tests, extras_test, intras_test,trains_with_limits,max_samples)
#
# ~/texasfile/paper_codes/QPIA-UNET/pia_unet_quantile.py in train_and_save_model_quantile(hyperparams, loc, data, trains, tests, extras_test, intras_test, trains_with_limits, max_samples)
#     613     return loss
#     614 def train_and_save_model_quantile(hyperparams,  loc, data, trains, tests, extras_test, intras_test,trains_with_limits, max_samples):
# --> 615     model = train_model(data,trains_with_limits, max_samples, trains, tests, **hyperparams)
#     616     new_dic = {}
#     617     for i in [ 'seed', 'kernel_size', 'ch_num', 'depth','wph', 'lr', 'epoch', 'physics', 'max_sample', ]:
#
# ~/texasfile/paper_codes/QPIA-UNET/pia_unet_quantile.py in train_model(data, trains_with_limits, max_samples, train_sets, test_sets, **kwargs)
#     582             metrics=["mean_absolute_error"]
#     583         )
# --> 584         hist, model = model_fit_physics(
#     585             model,
#     586             extras_train,
#
# ~/texasfile/paper_codes/QPIA-UNET/pia_unet_quantile.py in model_fit_physics(model, train_input1, val_input1, train_target1, val_target1, n_epoch, batch_size, quantile)
#     456     # dv_out,dv_t,dv2_t,a,k*1000,x,t_,dv_l,dv_r,t_out
#     457     if quantile:
# --> 458           history = model.fit(x=train_input1, y=[train_target1,train_target1,train_target1,
#     459                                            dummy_train_ode,dummy_train_ode,dummy_train_ode,
#     460                                            dummy_train_dv,dummy_train_dv,dummy_train_dv,
#
# /usr/lib/python3/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/lib/python3/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1740                         ):
#    1741                             callbacks.on_train_batch_begin(step)
# -> 1742                             tmp_logs = self.train_function(iterator)
#    1743                             if data_handler.should_sync:
#    1744                                 context.async_wait()
#
# /usr/lib/python3/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     823
#     824       with OptionalXlaContext(self._jit_compile):
# --> 825         result = self._call(*args, **kwds)
#     826
#     827       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     871       # This is the first call of __call__, so we have to initialize.
#     872       initializers = []
# --> 873       self._initialize(args, kwds, add_initializers_to=initializers)
#     874     finally:
#     875       # At this point we know that the initialization is complete (or less
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     692     # Force the definition of the function for these arguments
#     693     self._concrete_variable_creation_fn = (
# --> 694         self._variable_creation_fn    # pylint: disable=protected-access
#     695         ._get_concrete_function_internal_garbage_collected(
#     696             *args, **kwds))
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#     174     """Returns a concrete function which cleans up its graph function."""
#     175     with self._lock:
# --> 176       concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     177     return concrete_function
#     178
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_concrete_function(self, args, kwargs)
#     169       kwargs = {}
#     170
# --> 171     return self._maybe_define_function(args, kwargs)
#     172
#     173   def _get_concrete_function_internal_garbage_collected(self, *args, **kwargs):
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _maybe_define_function(self, args, kwargs)
#     396           kwargs = placeholder_bound_args.kwargs
#     397
# --> 398           concrete_function = self._create_concrete_function(
#     399               args, kwargs, func_graph)
#     400
#
# /usr/lib/python3/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in _create_concrete_function(self, args, kwargs, func_graph)
#     303
#     304     concrete_function = monomorphic_function.ConcreteFunction(
# --> 305         func_graph_module.func_graph_from_py_func(
#     306             self._name,
#     307             self._python_function,
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     985     deps_control_manager = ops.NullContextmanager()
#     986
# --> 987   with func_graph.as_default(), deps_control_manager as deps_ctx:
#     988     current_scope = variable_scope.get_variable_scope()
#     989     default_use_resource = current_scope.use_resource
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     457       # Check for any resource inputs. If we find any, we update control_inputs
#     458       # and last_write_to_resource.
# --> 459       for inp, resource_type in _get_resource_inputs(op):
#     460         is_read = resource_type == ResourceType.READ_ONLY
#     461         input_id = ops.tensor_id(inp)
#
# /usr/lib/python3/dist-packages/tensorflow/python/framework/auto_control_deps.py in _get_resource_inputs(op)
#     615       # TODO(srbs): An alternate would be to just compare the old and new set
#     616       # but that may not be as fast.
# --> 617       updated = _acd_resource_resolvers_registry.lookup(key)(op, reads, writes)
#     618       if updated:
#     619         # Conservatively remove any resources from `reads` that are also writes.
#
# KeyboardInterrupt:
